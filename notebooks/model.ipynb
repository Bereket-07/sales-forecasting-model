# %%
import sys , os 

sys.path.append(os.path.abspath('../scripts/model_training'))

# %%
import pipeline as pl

# %%
path = '../data/train.csv'
pipeline = pl.main(path)
# Out:
# INFO:pipeline:Loading the dataset
# c:\Users\bekib\Desktop\10ACADAMY\WEEK-FOUR\week-4\scripts\model_training\pipeline.py:86: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(path)
# INFO:pipeline:Separating the target variable
# INFO:pipeline:Target variable split complete
# INFO:pipeline:Splitting the data into train and test sets
# INFO:pipeline:Data split complete
# INFO:pipeline:Creating the sklearn pipeline
# INFO:pipeline:Sklearn pipeline created
# INFO:pipeline:Defining parameter grid
# INFO:pipeline:Parameter grid defined
# INFO:pipeline:Setting up GridSearchCV
# INFO:pipeline:GridSearchCV setup complete
# INFO:pipeline:Fitting the GridSearchCV
# INFO:pipeline:Converting categorical columns to numerical columns
# INFO:pipeline:Extracting new features
# INFO:pipeline:Converting categorical columns to numerical columns
# INFO:pipeline:Extracting new features
# ...
